# %%
import random

type(random)
# Out:
# module

# %%
print(random.random())
# Out:
# 0.06552885923981311

# %%
random.choice([1,2,3,4])
# Out:
# 3

# %% [markdown]
# Computers don’t generate true randomness — they generate pseudo-random numbers based on an initial value (the seed).

# %%
random.seed(34)
print(random.random())
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.5289353829404123
# 0.5857468547498617
# 0.8433262052335756
# 0.8986446412645931

# %%
random.randint(0,12)
# Out:
# 5

# %%
random.randint(-10,-1)
# Out:
# -4

# %%
s = "python"
random.choice(s)
# Out:
# 't'

# %%
random.sample([1,2,34,5,2,1],3)
# Out:
# [1, 34, 2]

# %%
a = [1,3,2,45,5,3,2,1]
random.shuffle(a)
print(a)
# Out:
# [2, 3, 2, 45, 1, 1, 3, 5]

# %%
random.getstate()
# Out:
# (3,
#  (824450157,
#   3704675724,
#   3416573671,
#   3464514427,
#   3503838605,
#   3146713906,
#   913122656,
#   2684352477,
#   2282193264,
#   2013102892,
#   2246462780,
#   463328872,
#   1913068359,
#   1498327202,
#   2130028136,
#   3882066390,
#   3239997293,
#   2267822349,
#   628336292,
#   229110857,
#   3048183560,
#   2546559784,
#   4147281259,
#   1698638460,
#   867556114,
#   957780306,
#   652323699,
#   2409463928,
#   2621397545,
#   3622850690,
#   4168286686,
#   1096463117,
#   1519899054,
#   2054170672,
#   4160116328,
#   3679811992,
#   3056416761,
#   3803765808,
#   3141010181,
#   4024591654,
#   3936703029,
#   1587616233,
#   1611628262,
#   3302855778,
#   2032493103,
#   980897754,
#   316489055,
#   3625806888,
#   622124829,
#   2269798744,
#   2148005147,
#   2207034775,
#   2567548778,
#   163057858,
#   2119246776,
#   1406994867,
#   2287024196,
#   451367467,
#   2647052657,
#   1301422835,
#   1393600992,
#   1709441202,
#   342916697,
# ...

# %%
random.randrange(10,12)
# Out:
# 10

# %%
random.uniform(10,11)
# Out:
# 10.159159054683121

# %%
random.gauss(12,0.9)
# Out:
# 11.581456968729515
