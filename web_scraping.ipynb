# %%
import requests

# %%
result = requests.get('https://www.google.com')

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="uPnNQCfYjLlVj4E5e-YF4A">(function(){var _g={kEI:\'ZwWPaYGNNr7YkPIP_M7FuQU\',kEXPI:\'0,1304203,2935842,48791,30022,16105,78218,123649,142929,301150,5219175,12640,36811403,25306697,74362,65175,39768,75317,23254,37805,28334,65615,13699,7714,14750,18635,3050,2,23178,2864,22727,30421,15916,9923,10754,10126,1760,6437,9742,2646,6289,12451,1167,822,2,2,3513,14506,1382,2,1,1515,3355,2,194,5814,2,4205,3,3212,7072,5814,2,874,23,2208,5089,19,3008,29,766,4081,4,5386,13783,9017,3102,1250,1034,4303,311,12,1,521,846,1200,2,12,16,1545,3,5204,2,12,723,1010,1747,4,15193,4,2171,72,241,296,5,1113,389,4,2647,5,5568,298,6256,2997,848,427,7,1784,7,1049,2,1912,1947,8510,2,5724,9,602,96,1553,4,1613,1772,2544,915,3664,1,2,803,3
# ...

# %%
import bs4

# %%
soup  = bs4.BeautifulSoup(result.text,"lxml")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.select('title')
# Out:
# [<title>Google</title>]

# %%
soup.select('title')[0].getText()
# Out:
# 'Google'

# %%
soup.select('.gb_Z') #class
# Out:
# []

# %%
soup.select('#LS8OJ') #id
# Out:
# []

# %%
import requests
import bs4

# %%
re = requests.get('https://chatgpt.com/')
print(re.text)
# Out:
# <html>
#   <head>
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style global>body{font-family:Arial,Helvetica,sans-serif}.container{align-items:center;display:flex;flex-direction:column;gap:2rem;height:100%;justify-content:center;width:100%}@keyframes enlarge-appear{0%{opacity:0;transform:scale(75%) rotate(-90deg)}to{opacity:1;transform:scale(100%) rotate(0deg)}}.logo{color:#8e8ea0}.scale-appear{animation:enlarge-appear .4s ease-out}@media (min-width:768px){.scale-appear{height:48px;width:48px}}.data:empty{display:none}.data{border-radius:5px;color:#8e8ea0;text-align:center}@media (prefers-color-scheme:dark){body{background-color:#343541}.logo{color:#acacbe}}</style>
#   <meta http-equiv="refresh" content="360">
# </head>
#   <body>
#     <div class="container">
#       <div class="logo">
#         <svg
#           width="41"
#           height="41"
#           viewBox="0 0 41 41"
#           fill="none"
# ...

# %%
# soup = bs4.BeautifulSoup(re.text,"lxml")
soup = bs4.BeautifulSoup(re.text,'html.parser')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <style global="">
#    body{font-family:Arial,Helvetica,sans-serif}.container{align-items:center;display:flex;flex-direction:column;gap:2rem;height:100%;justify-content:center;width:100%}@keyframes enlarge-appear{0%{opacity:0;transform:scale(75%) rotate(-90deg)}to{opacity:1;transform:scale(100%) rotate(0deg)}}.logo{color:#8e8ea0}.scale-appear{animation:enlarge-appear .4s ease-out}@media (min-width:768px){.scale-appear{height:48px;width:48px}}.data:empty{display:none}.data{border-radius:5px;color:#8e8ea0;text-align:center}@media (prefers-color-scheme:dark){body{background-color:#343541}.logo{color:#acacbe}}
#   </style>
#   <meta content="360" http-equiv="refresh"/>
#  </head>
#  <body>
#   <div class="container">
#    <div class="logo">
#     <svg class="scale-appear" fill="none" height="41" strokewidth="2" viewbox="0 0 41 41" width="41" xmlns="http://www.w3.org/2000/svg">
# ...

# %%
soup.select(".logo")[0].getText()
# Out:
# '\n\n\n\n'
