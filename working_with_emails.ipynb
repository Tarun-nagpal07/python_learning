# %%
import smtplib

# %%
smtp_object = smtplib.SMTP('smtp.gmail.com',587)

# %%
smtp_object.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [49.200.158.22]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_object.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
import smtplib
from email.message import EmailMessage

# %%
msg = EmailMessage()
msg["Subject"] = "Test Email"
msg["From"] = "tarunnagpal192004@gmail.com"
msg["To"] = "sahil.bhatia@simformsolutions.com"
msg.set_content("Kero haal tai bhaauu?")

# msg.add_alternative("""
# <html>
#     <body>
#         <h1>Hello!</h1>
#         <p>This is an <b>HTML</b> email.</p>
#     </body>
# </html>
# """, subtype="html")

# with open("file.pdf", "rb") as f:
#     file_data = f.read()
#     file_name = f.name

# msg.add_attachment(
#     file_data,
#     maintype="application",
#     subtype="pdf",
#     filename=file_name
# )

# %%
with smtplib.SMTP("smtp.gmail.com",587) as server:
    server.starttls()
    server.login("tarunnagpal192004@gmail.com","")
    server.send_message(msg)
